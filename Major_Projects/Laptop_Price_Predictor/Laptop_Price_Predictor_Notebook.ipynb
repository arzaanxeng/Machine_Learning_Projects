# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df = df.drop(columns = ['Unnamed: 0'] , axis = 1)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches   ScreenResolution  \
# 568  Lenovo  Notebook    15.6  Full HD 1920x1080
#
#                                       Cpu  Ram     Memory  \
# 568  Intel Pentium Quad Core N4200 1.1GHz  4GB  500GB HDD
#
#                        Gpu       OpSys Weight     Price
# 568  Intel HD Graphics 505  Windows 10  2.2kg  18328.32

# %% [markdown]
# # EDA

# %%
df['Ram'] = df['Ram'].str.replace("GB" , "")
df['Weight'] = df['Weight'].str.replace("kg" , "")
df['Ram'] = df['Ram'].astype(int)
df['Weight'] = df['Weight'].astype(float)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 367   Lenovo    Gaming    15.6  IPS Panel Full HD 1920x1080
# 1090    Dell  Notebook    15.6                     1366x768
# 87        HP  Notebook    15.6            Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 367            Intel Core i5 7300HQ 2.5GHz    8  128GB SSD +  1TB HDD
# 1090  Intel Pentium Quad Core N3700 1.6GHz    4             500GB HDD
# 87              Intel Core i5 7200U 2.5GHz    8             256GB SSD
#
#                           Gpu       OpSys  Weight       Price
# 367   Nvidia GeForce GTX 1050       No OS    2.40  43103.5200
# 1090        Intel HD Graphics       Linux    2.20  20965.1472
# 87      Intel HD Graphics 620  Windows 10    1.96  31914.1872

# %%
sns.pairplot(df)

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
sns.barplot(df , x = 'Company' , y = 'Price' , palette = 'pastel')
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# **Prices seems to be distributed not so evenly based upon companies but we can notice that Razer has some expensive stuff**

# %%
df.sample()
# Out:
#      Company  TypeName  Inches   ScreenResolution                         Cpu  \
# 1063    Dell  Notebook    15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
#
#       Ram   Memory                 Gpu       OpSys  Weight       Price
# 1063   16  2TB HDD  AMD Radeon R7 M445  Windows 10    2.32  52746.6672

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1
sns.barplot(data=df, x='TypeName', y='Price', palette='pastel', ax=ax[0])
ax[0].tick_params(axis='x', rotation=90)
ax[0].set_title('Average Price by Laptop Type')

# Plot 2
df['TypeName'].value_counts().plot(kind='bar', ax=ax[1])
ax[1].set_title('Count of Laptop Types')
ax[1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# **We can see notebook is highly sold due to lower prices while Gaming , Ultrabooks fall around the best budget price fit laptops**

# %%
sns.barplot(df , x = 'Ram' , y = 'Price' , palette = 'pastel')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.corr(numeric_only = True )
# Out:
#           Inches       Ram    Weight     Price
# Inches  1.000000  0.237993  0.827631  0.068197
# Ram     0.237993  1.000000  0.383874  0.743007
# Weight  0.827631  0.383874  1.000000  0.210370
# Price   0.068197  0.743007  0.210370  1.000000

# %% [markdown]
# **We all know the better the PPI of the screens the greater is the price segment of the laptop!**
#
# **Lets's try to extract some information regarding screens of the Laptops to analyze the cost more efficiently**

# %%
df.sample()
# Out:
#     Company TypeName  Inches             ScreenResolution  \
# 987  Lenovo   Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 987  Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight     Price
# 987  Nvidia GeForce GTX 1060  Windows 10     2.5  63349.92

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df['Touchscreen'] = df['Touchscreen'].astype(int)
df['IPS'] = df['IPS'].astype(int)

# %%
df.sample(4)
# Out:
#     Company  TypeName  Inches   ScreenResolution  \
# 127    Asus  Notebook    14.0           1366x768
# 537      HP  Notebook    15.6  Full HD 1920x1080
# 941    Asus  Notebook    17.3           1600x900
# 260    Dell  Notebook    17.3  Full HD 1920x1080
#
#                                       Cpu  Ram                Memory  \
# 127              AMD E-Series 6110 1.5GHz    4              64GB SSD
# 537  Intel Pentium Quad Core N3710 1.6GHz    4             256GB SSD
# 941  Intel Pentium Quad Core N3710 1.6GHz    4               1TB HDD
# 260            Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
#
#                        Gpu         OpSys  Weight       Price  Touchscreen  IPS
# 127          AMD Radeon R2  Windows 10 S    1.65  14811.3072            0    0
# 537  Intel HD Graphics 405    Windows 10    1.86  21258.1872            0    0
# 941   Nvidia GeForce 920MX    Windows 10    2.80  28238.4000            0    0
# ...

# %%
df.corr(numeric_only = True)
# Out:
#                Inches       Ram    Weight     Price  Touchscreen       IPS
# Inches       1.000000  0.237993  0.827631  0.068197    -0.361735 -0.114804
# Ram          0.237993  1.000000  0.383874  0.743007     0.116984  0.206623
# Weight       0.827631  0.383874  1.000000  0.210370    -0.294620  0.016967
# Price        0.068197  0.743007  0.210370  1.000000     0.191226  0.252208
# Touchscreen -0.361735  0.116984 -0.294620  0.191226     1.000000  0.150512
# IPS         -0.114804  0.206623  0.016967  0.252208     0.150512  1.000000

# %%
x = df['ScreenResolution'].str.split('x' , expand = True)
df['x'] = x[0]
df['y'] = x[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['x'] = df['x'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df = df.drop(columns = ['ScreenResolution'] , axis = 1)

# %%
df['x'] = df['x'].astype(int)
df['y'] = df['y'].astype(int)

# %%
df['ppi'] = (((df['x']**2) + (df['y']**2))**0.5/df['Inches']).astype('float')
df = df.drop(columns = ['x'] , axis = 1)
df = df.drop(columns = ['y'] , axis = 1)

# %%
df.sample()
# Out:
#     Company            TypeName  Inches                        Cpu  Ram  \
# 970    Dell  2 in 1 Convertible    13.3  Intel Core i7 7Y75 1.3GHz   16
#
#         Memory                    Gpu       OpSys  Weight      Price  \
# 970  512GB SSD  Intel HD Graphics 615  Windows 10    1.22  101178.72
#
#      Touchscreen  IPS        ppi
# 970            1    0  276.05353

# %%
df.corr(numeric_only = True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# ppi            0.473487
# Name: Price, dtype: float64

# %% [markdown]
# **Clearly a good co relation between ppi and price seems to be there**

# %%
df['Cpu'].value_counts()
# TOO MANY :(
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi       Cpu Name
# 0   71378.6832            0    1  226.983005  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5
# ...

# %%
	
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi       Cpu Name      Cpu brand
# 0   71378.6832            0    1  226.983005  Intel Core i5  Intel Core i5
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Plot 1
sns.barplot(data=df, x='Cpu brand', y='Price', palette='pastel', ax=ax[0])
ax[0].tick_params(axis='x', rotation=90)
ax[0].set_title('Average Price by Laptop Type')

# Plot 2
df['Cpu brand'].value_counts().plot(kind='bar', ax=ax[1])
ax[1].set_title('Count of Laptop Types')
ax[1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
# 3   Apple  Ultrabook    15.4   16            512GB SSD
# 4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# ...

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '', regex=True)

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '', regex=True)

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
# 2      HP   Notebook    15.6    8            256 SSD
# 3   Apple  Ultrabook    15.4   16            512 SSD
# 4   Apple  Ultrabook    13.3    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5    0  128       0              0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)
df.corr(numeric_only = True)['Price']
# Out:
# Inches           0.068197
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
# Hybrid , Flash Storage seeems to be useless os gonna kick them out
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
df.sample()
# Out:
#     Company  TypeName  Inches  Ram                   Gpu       OpSys  Weight  \
# 217      HP  Notebook    14.0    8  Nvidia GeForce 930MX  Windows 10    1.63
#
#         Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD Gpu brand
# 217  54931.68            0    0  157.350512  Intel Core i7    0  256    Nvidia

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df = df.drop(columns=['Gpu'])

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

df['os'] = df['OpSys'].apply(cat_os)
df.head()
# Out:
#   Company   TypeName  Inches  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    13.3    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    13.3    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    15.6    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook    15.4   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    13.3    8  macOS    1.37   96095.8080            0
#
#    IPS         ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0    1  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1    0  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2    0  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3    1  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4    1  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df = df.drop(columns=['OpSys'])

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot((df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['Price'])
y = np.log(df['Price'])
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# Categorical columns only
categorical_cols = [
    'Company',
    'TypeName',
    'Cpu brand',
    'Gpu brand',
    'os'
]

step1 = ColumnTransformer(
    transformers=[
        (
            'cat',
            OneHotEncoder(
                drop='first',
                sparse_output=False,
                handle_unknown='ignore'
            ),
            categorical_cols
        )
    ],
    remainder='passthrough'   # keep all numeric columns
)

step2 = RandomForestRegressor(
    n_estimators=100,
    random_state=3,
    max_samples=0.5,
    max_features=0.75,
    max_depth=15
)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Metrics
print("R2 Score :", r2_score(y_test, y_pred))
print("MAE :", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score : 0.860112412290196
# MAE : 0.17562808795891702

# %%
import pickle

pickle.dump(df,open('data.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
print(X.columns.tolist())
# Out:
# ['Company', 'TypeName', 'Inches', 'Ram', 'Weight', 'Touchscreen', 'IPS', 'ppi', 'Cpu brand', 'HDD', 'SSD', 'Gpu brand', 'os']
